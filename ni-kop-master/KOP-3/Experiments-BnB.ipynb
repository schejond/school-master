# %% [markdown]
# ## Notebook for experimenting with Branch and Bound algorithm

# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np
from statistics import mean
import os

# %matplotlib inline 
matplotlib.style.use('ggplot')

# %%
def parseParamsFromName(fileName):
    split = fileName.split("_")
    if len(split) is not 3 and len(split) is not 4:
        raise ValueError('Unexpected fileName: ' + fileName)
        
    if len(split) is 3:
        return split[0], split[1], split[2], 1
    else:
        return split[0], split[1], split[2], split[3]

# %%
def prepareDFCols(dirName, fileName):
    file_df = pd.read_csv(dirName + fileName)
    
    weightDist, priceWCorel, knapsackKapRatio, k = parseParamsFromName(fileName[:-4])
    
    file_df = file_df.assign(w_dist=weightDist)
    file_df = file_df.assign(c_w_corr=priceWCorel)
    file_df = file_df.assign(c_w_ratio=knapsackKapRatio)
    file_df = file_df.assign(k=k)
    
    return file_df

# %%
# load data from folder, create important columns and concat all files into 1 df
def loadDF(dirName):
    df = None
    
    for fileName in os.listdir(dirName):
        if df is None:
            df = prepareDFCols(dirName, fileName)
        else:
            df = pd.concat([df, prepareDFCols(dirName, fileName)], ignore_index=True)

    # make all ids positive
    df['KnapsackId'] = abs(df['KnapsackId'])
    return df

# %%
# definice pouzitelnych promennych
ROOT_FOLDER_NAME = './Output/'
params_w = ['bal', 'light', 'heavy']
params_c = ['uni', 'corr', 'strong']
params_m = {
    0.01: '001',
    0.25: '025',
    0.5: '05',
    0.8: '08',
    1: '1'
}

bnb = 'BranchAndBound'
# greedy = 'Greedy'
# dp = 'DP_PD'

# %%
# ziskani pozadovanych dat
df = loadDF(ROOT_FOLDER_NAME + bnb + '/')

display(df.head())
# Out:
#    KnapsackId  NumberOfItems  CpuTime  NodesVisited  Error w_dist c_w_corr  \
# 0           1             20      0.0             5    0.0    bal     corr
# 1           2             20      0.0             4    0.0    bal     corr
# 2           3             20      0.0             2    0.0    bal     corr
# 3           4             20      0.0             1    0.0    bal     corr
# 4           5             20      0.0             2    0.0    bal     corr
#
#   c_w_ratio  k
# 0       001  1
# 1       001  1
# 2       001  1
# 3       001  1
# 4       001  1

# %%
# load results.csv
res = pd.read_csv('results.csv')
res = res[res['AlgoName'] == bnb]
for index, row in res.iterrows():
    weightDist, priceWCorel, knapsackKapRatio, k = parseParamsFromName(row['FileName'])
    res.loc[index, 'w_dist'] = weightDist
    res.loc[index, 'c_w_corr'] = priceWCorel
    res.loc[index, 'c_w_ratio'] = knapsackKapRatio
    res.loc[index, 'k'] = k
    
display(res.head())
# Out:
#            FileName        AlgoName   CpuTime        Date w_dist c_w_corr  \
# 45      bal_uni_001  BranchAndBound  0.140625  2020-11-13    bal      uni
# 46  heavy_strong_08  BranchAndBound  0.140625  2020-11-13  heavy   strong
# 47      bal_uni_025  BranchAndBound  0.093750  2020-11-13    bal      uni
# 48  light_strong_08  BranchAndBound  0.078125  2020-11-13  light   strong
# 49       bal_uni_05  BranchAndBound  0.093750  2020-11-13    bal      uni
#
#    c_w_ratio  k
# 45       001  1
# 46        08  1
# 47       025  1
# 48        08  1
# 49        05  1

# %%
# plot pilot data
columnName = 'NodesVisited'
i = 331
plt.figure(figsize=(25,15))

for w in params_w:
    for c in params_c:
        plt.subplot(i)
        for m in params_m.keys():
            plt.bar(
                m,
                df[(df['w_dist'] == w) & (df['c_w_corr'] == c)
                   & (df['c_w_ratio'] == params_m[m]) & (df['k'] == 1)
                  ][columnName].sum(),
                width = 0.15
            )
        plt.title(w + ' - ' + c)
        if w is params_w[-1]:
            plt.xlabel('m')
        if c is params_c[0]:
            plt.ylabel('Celkový počet navštívených nodů')
        i += 1

# %%
# bigger weight
columnName = 'NodesVisited'
i = 121
plt.figure(figsize=(10,4))

plt.subplot(i)
for m in params_m.keys():
    plt.bar(m,
            df[(df['w_dist'] == 'bal') & (df['c_w_corr'] == 'uni')
               & (df['c_w_ratio'] == params_m[m]) & (df['k'] == '099')
              ][columnName].sum(),
            width = 0.15
           )
plt.title('bal - uni - bigger max weight')
plt.xlabel('m')
plt.ylabel('Celkový počet navštívených nodů')
i += 1

# bigger price
plt.subplot(i)
for m in params_m.keys():
    plt.bar(m,
            df[(df['w_dist'] == 'bal') & (df['c_w_corr'] == 'uni')
               & (df['c_w_ratio'] == params_m[m]) & (df['k'] == '098')
              ][columnName].sum(),
            width = 0.15
           )
plt.title('bal - uni - bigger max price')
plt.xlabel('m')
plt.show()

# %%
print(np.linspace(-2, 2.5, 7))
params_k = {
    -2: 'm2',
    -1.25: 'm125',
    -0.5: 'm05',
    0.25: '025',
    1: '1',
    1.75: '175',
    2.5: '25'
}
# Out:
# [-2.   -1.25 -0.5   0.25  1.    1.75  2.5 ]

# %%
# big experiment data plotting
columnName = 'NodesVisited'
i = 121
plt.figure(figsize=(10,4))

# bal - uni
plt.subplot(i)
for k in params_k.keys():
    plt.bar(k,
            df[(df['w_dist'] == 'bal') & (df['c_w_corr'] == 'uni')
               & (df['c_w_ratio'] == '051') & (df['k'] == params_k[k])
              ][columnName].sum(),
            width = 0.5
           )
plt.title('bal - uni - m = 0.5')
plt.xlabel('k')
plt.ylabel('Celkový počet navštívených nodů')
i += 1

# heavy - strong
plt.subplot(i)
for k in params_k.keys():
    plt.bar(k,
            df[(df['w_dist'] == 'heavy') & (df['c_w_corr'] == 'strong')
               & (df['c_w_ratio'] == '051') & (df['k'] == params_k[k])
              ][columnName].sum(),
            width = 0.5
           )
plt.title('heavy - strong - m = 0.5')
plt.xlabel('k')
plt.show()

# %%
# # big experiment data plotting - CPU
# i = 121
# plt.figure(figsize=(8,3))

# # heavy - strong
# plt.subplot(i)
# for k in params_k.keys():
#     plt.bar(k,
#             df[(df['w_dist'] == 'heavy') & (df['c_w_corr'] == 'strong')
#                & (df['c_w_ratio'] == '051') & (df['k'] == params_k[k])
#               ]['CpuTime'].sum()
#            )
# plt.title('heavy - strong - m = 0.5')
# plt.xlabel('k')
# plt.ylabel('Celkový CPU Time v sekundách')
# i += 1

# # bal - uni
# plt.subplot(i)
# for k in params_k.keys():
#     plt.bar(k,
#             df[(df['w_dist'] == 'bal') & (df['c_w_corr'] == 'uni')
#                & (df['c_w_ratio'] == '051') & (df['k'] == params_k[k])
#               ]['CpuTime'].sum()
#            )
# plt.title('bal - uni - m = 0.5')
# plt.xlabel('k')
# plt.show()

# %%
# def getFinalTable(resCsv, df, folderName, algoName):
#     df_final = pd.DataFrame(columns=['n', 'Avg_Err', 'Avg_Cpu_Time', 'Max_Cpu', 'Max_Err', 'Total_CPU'])
#     if 'Error' not in df.columns:
#         df['Error'] = 0
#     for n in df.NumberOfItems.unique():
#         row_data = [
#             n,
#             df[df.NumberOfItems == n]['Error'].mean(),
#             resCsv.loc[(resCsv['n'] == str(n)) & (resCsv['AlgoName'] == algoName) & (resCsv['folder'] == folderName)].iloc[0].CpuTime/len(df[df.NumberOfItems == n]),
#             df[df.NumberOfItems == n]['CpuTime'].max(),
#             df[df.NumberOfItems == n]['Error'].max(),
#             resCsv.loc[(resCsv['n'] == str(n)) & (resCsv['AlgoName'] == algoName) & (resCsv['folder'] == folderName)].iloc[0].CpuTime
#         ]
#         df_final.loc[len(df_final)] = row_data
#     return df_final

# %%
# df = getFinalTable(res, df_bnb, fn, bnb)

# display(df.head(2))
